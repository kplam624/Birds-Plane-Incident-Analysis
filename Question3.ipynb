# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
database="Resources/Cleaned_data.csv"
cbs_df=pd.read_csv(database, low_memory=False)

# %% [markdown]
# # Bar Graph Bird Strikes by Flight Phase

# %%
cbs_df=cbs_df.loc[cbs_df['Flight Phase']!='0']
phase_df=cbs_df['Flight Phase'].value_counts()
bar_chart=phase_df.plot(kind='bar', color='blue', fontsize=10, figsize=(10,4))
plt.xticks(rotation=45)
bar_chart.set_title('Bird Strikes by Flight Phase (1990-2015)', fontsize=20)
bar_chart.set_xlabel('Flight Phase', fontsize=15)
bar_chart.set_ylabel('Bird Strikes', fontsize=15)
plt.grid()
plt.savefig("Output_data/BSbyPhase.png",bbox_inches='tight')
plt.show()
phase_df
# Out:
# APPROACH        48045
# TAKEOFF RUN     21647
# LANDING ROLL    20539
# CLIMB           19548
# DESCENT          3162
# EN ROUTE         2960
# LANDING           626
# TAXI              384
# DEPARTURE         368
# LOCAL             300
# ARRIVAL           153
# PARKED             95
# Name: Flight Phase, dtype: int64
